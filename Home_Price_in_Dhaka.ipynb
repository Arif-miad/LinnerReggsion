# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("/dhaka homeprices.csv")

# %%
df
# Out:
#    area   price
# 0  2600   55000
# 1  3000   56500
# 2  3200   61000
# 3  3600   68000
# 4  4000   72000
# 5  5000   71000
# 6  2500   40000
# 7  2700   38000
# 8  1200   17000
# 9  5000  100000

# %%
df.head(4)
# Out:
#    area  price
# 0  2600  55000
# 1  3000  56500
# 2  3200  61000
# 3  3600  68000

# %%
df.shape
# Out:
# (10, 2)

# %%
df.isnull().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
x = df[['area']]
y = df['price']

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000
# 5  5000
# 6  2500
# 7  2700
# 8  1200
# 9  5000

# %%
y
# Out:
# 0     55000
# 1     56500
# 2     61000
# 3     68000
# 4     72000
# 5     71000
# 6     40000
# 7     38000
# 8     17000
# 9    100000
# Name: price, dtype: int64

# %%
plt.scatter(df['area'],df['price'],marker='+',color='red')
plt.xlabel("Aria in square ft")
plt.ylabel("Price in taka")
plt.title("Home prices in Dhaka")
# Out:
# Text(0.5, 1.0, 'Home prices in Dhaka')

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.30,random_state=1)

# %%
xtrain
# Out:
#    area
# 4  4000
# 0  2600
# 3  3600
# 1  3000
# 7  2700
# 8  1200
# 5  5000

# %%
xtest
# Out:
#    area
# 2  3200
# 9  5000
# 6  2500

# %%
ytrain
# Out:
# 4    72000
# 0    55000
# 3    68000
# 1    56500
# 7    38000
# 8    17000
# 5    71000
# Name: price, dtype: int64

# %%
ytest
# Out:
# 2     61000
# 9    100000
# 6     40000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
reg.predict(xtest)
# Out:
# array([54577.95521897, 81852.07441554, 43971.35330919])

# %%
plt.scatter(df['area'],df['price'],marker='+',color='red')
plt.xlabel("Area in squere ft")
plt.ylabel("Price in taka")
plt.title("Home prise Dhaka")
plt.plot(df.area,reg.predict(df[['area']]))
plt.plot(df.area,reg.predict(df[['area']]))

# %%
reg.predict([[350]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([11393.93315772])

# %%
reg.coef_
# Out:
# array([15.15228844])

# %%
reg.intercept_
# Out:
# 6090.632202831752

# %%
y =15.15228844*3900+6090.632202831752

# %%
y
# Out:
# 65184.55711883175

# %%
plt.scatter(df['area'],df['price'],marker='+',color='red')
plt.xlabel("Aria in square ft")
plt.ylabel("Price in taka")
plt.title("Home prices in Dhaka")
# Out:
# Text(0.5, 1.0, 'Home prices in Dhaka')

# %%
plt.scatter(df['area'],df['price'],marker='+',color='red')
plt.xlabel("Aria in square ft")
plt.ylabel("Price in taka")
plt.title("Home prices in Dhaka")
# Out:
# Text(0.5, 1.0, 'Home prices in Dhaka')
